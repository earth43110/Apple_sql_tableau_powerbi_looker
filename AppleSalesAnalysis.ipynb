# %% [markdown]
# # <u>Apple Sales Retail Analysis Report</u>
# *Tools used: SQL*

# %% [markdown]
# # <u>Extract, Transform, Load Process (ETL)</u>

# %% [markdown]
# ### Load the ipython-sql extension

# %%
# Load the ipython-sql extension
# %load_ext sql

# Connect to the PostgreSQL database (replace with your credentials)
# %sql postgresql://uauixbmmi7hdbhbtx1pg:MhJAS62A8ExDnsRIxVK40ab3snEIO2@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw

# Fix formatting issue with extension
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Import csv files into new SQL tables

# %%
"""
# !pip install sqlalchemy-utils
import os
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database

# Create SQLAlchemy engine for PostgreSQL
database_url = "postgresql://uauixbmmi7hdbhbtx1pg:MhJAS62A8ExDnsRIxVK40ab3snEIO2@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw"
engine = create_engine(database_url)

# List of CSV files to import
csv_files = ['https://drive.google.com/file/d/1Nr2R0fHxvJ4e-ULoN6ltjlm5ePuchHAl/view?usp=drive_link',
             'https://drive.google.com/file/d/1_-SdyqN9ElxYUY2YRwW7SjcqQ3NiUMDF/view?usp=drive_link',
             'https://drive.google.com/file/d/1-HN1-UhCPOkHpmFLDPEZZV7rytTyEnRY/view?usp=drive_link',
             'https://drive.google.com/file/d/1F8lCQVGPYn7VD6cZ_tg0bFEgH9qVNT83/view?usp=drive_link',
             'https://drive.google.com/file/d/1JCcn4hLCkSSes21ZPzUMuH1KxZHpjqLl/view?usp=drive_link']  # Add your file names here

# Convert the URLs to direct download format
download_urls = ['https://drive.google.com/uc?id=' + url.split('/')[-2] for url in csv_files]

# List of table names
table_names = ['warranty', 'stores', 'sales', 'products', 'category']  # Replace with your CSV file names

# Loop through each CSV file and corresponding table name
for url, table_name in zip(download_urls, table_names):
    # Read CSV into a pandas DataFrame
    df = pd.read_csv(url)

    # Write DataFrame to SQL as a new table
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)

    print(f"Table '{table_name}' created and data inserted from {url}.")
"""
# Out:
# '\n!pip install sqlalchemy-utils\nimport os\nimport pandas as pd\nfrom sqlalchemy import create_engine\nfrom sqlalchemy_utils import database_exists, create_database\n\n# Create SQLAlchemy engine for PostgreSQL\ndatabase_url = "postgresql://uauixbmmi7hdbhbtx1pg:MhJAS62A8ExDnsRIxVK40ab3snEIO2@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw"\nengine = create_engine(database_url)\n    \n# List of CSV files to import\ncsv_files = [\'https://drive.google.com/file/d/1Nr2R0fHxvJ4e-ULoN6ltjlm5ePuchHAl/view?usp=drive_link\', \n             \'https://drive.google.com/file/d/1_-SdyqN9ElxYUY2YRwW7SjcqQ3NiUMDF/view?usp=drive_link\', \n             \'https://drive.google.com/file/d/1-HN1-UhCPOkHpmFLDPEZZV7rytTyEnRY/view?usp=drive_link\',\n             \'https://drive.google.com/file/d/1F8lCQVGPYn7VD6cZ_tg0bFEgH9qVNT83/view?usp=drive_link\',\n             \'https://drive.google.com/file/d/1JCcn4hLCkSSes21ZPzUMuH1KxZHpjqLl/view?usp=drive_link\']  # Add your file 
# ...

# %% [markdown]
# ### Query all the tables to verify that they are loaded in correctly

# %%
# %%sql
# select * from warranty limit 3;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 3 rows affected.
# [('CL-285', datetime.date(2020, 1, 17), 'OID-363381', 'Free Replaced'),
#  ('CL-290', datetime.date(2020, 1, 19), 'OID-363359', 'Free Replaced'),
#  ('CL-291', datetime.date(2020, 1, 19), 'OID-363371', 'Free Replaced')]

# %%
# %%sql
# select * from stores limit 3;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 3 rows affected.
# [('ST-1', 'Apple Fifth Avenue', 'New York', 'USA'),
#  ('ST-2', 'Apple Union Square', 'San Francisco', 'USA'),
#  ('ST-3', 'Apple Michigan Avenue', 'Chicago', 'USA')]

# %%
# %%sql
# select * from sales limit 3;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 3 rows affected.
# [('OID-358365', datetime.date(2021, 9, 16), 'ST-33', 'P-44', 1),
#  ('OID-358510', datetime.date(2022, 1, 28), 'ST-33', 'P-44', 1),
#  ('OID-358525', datetime.date(2021, 11, 26), 'ST-33', 'P-44', 1)]

# %%
# %%sql
# select * from products limit 3;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 3 rows affected.
# [('P-1', 'MacBook Pro (Touch Bar)', 'CAT-1', datetime.date(2016, 10, 1), 1499),
#  ('P-2', 'AirPods', 'CAT-2', datetime.date(2016, 12, 1), 159),
#  ('P-3', 'iPad Pro (10.5-inch)', 'CAT-3', datetime.date(2017, 6, 1), 649)]

# %%
# %%sql
# select * from category limit 3;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 3 rows affected.
# [('CAT-1', 'Laptop'), ('CAT-2', 'Audio'), ('CAT-3', 'Tablet')]

# %% [markdown]
# ### <u>Change datatypes of specific columns</u>

# %% [markdown]
# ### Get the datatypes of the columns

# %%
# %%sql
# SELECT table_name, column_name, data_type
# FROM information_schema.columns
# WHERE table_name in ('warranty', 'stores', 'sales', 'products', 'category')
# group by 1,2,3;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 20 rows affected.
# [('category', 'category_id', 'text'),
#  ('category', 'category_name', 'text'),
#  ('products', 'category_id', 'text'),
#  ('products', 'launch_date', 'date'),
#  ('products', 'price', 'bigint'),
#  ('products', 'product_id', 'text'),
#  ('products', 'product_name', 'text'),
#  ('sales', 'product_id', 'text'),
#  ('sales', 'quantity', 'bigint'),
#  ('sales', 'sale_date', 'date'),
#  ('sales', 'sale_id', 'text'),
#  ('sales', 'store_id', 'text'),
#  ('stores', 'city', 'text'),
#  ('stores', 'country', 'text'),
#  ('stores', 'store_id', 'text'),
#  ('stores', 'store_name', 'text'),
#  ('warranty', 'claim_date', 'date'),
#  ('warranty', 'claim_id', 'text'),
#  ('warranty', 'repair_status', 'text'),
#  ('warranty', 'sale_id', 'text')]

# %% [markdown]
# ### Change datatype of date columns from text to date

# %%
# %%sql
#
# ALTER TABLE products
#   ALTER COLUMN launch_date
#   SET DATA TYPE date USING launch_date::date;
#
# ALTER TABLE sales
#   ALTER COLUMN sale_date
#   SET DATA TYPE date USING sale_date::date;
# ALTER TABLE warranty
#   ALTER COLUMN claim_date
#   SET DATA TYPE date USING claim_date::date;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# Done.
# Done.
# Done.
# []

# %% [markdown]
# # <u>Queries</u>

# %% [markdown]
# ### Confirm date range of data set

# %%
# %%sql
# select min(sales.sale_date) as earliest_date,
#   max(sales.sale_date) as latest_date
# from sales;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [(datetime.date(2019, 1, 2), datetime.date(2024, 8, 21))]

# %% [markdown]
# ### Q1. Find each country and number of stores

# %%
# %%sql
# select
# 	stores.country,
# 	count(*) as number_of_stores
# from stores
# group by country
# order by country;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 35 rows affected.
# [('Argentina', 1),
#  ('Australia', 3),
#  ('Bolivia', 1),
#  ('Brazil', 2),
#  ('Canada', 8),
#  ('Chile', 1),
#  ('China', 4),
#  ('Costa Rica', 1),
#  ('Dominican Republic', 1),
#  ('France', 2),
#  ('Germany', 2),
#  ('India', 2),
#  ('Indonesia', 1),
#  ('Italy', 1),
#  ('Japan', 2),
#  ('Malaysia', 1),
#  ('Mexico', 1),
#  ('Netherlands', 1),
#  ('Peru', 1),
#  ('Philippines', 1),
#  ('Qatar', 1),
#  ('Saudi Arabia', 1),
#  ('Singapore', 1),
#  ('South Korea', 1),
#  ('Spain', 2),
#  ('Switzerland', 1),
#  ('Taiwan', 1),
#  ('Thailand', 1),
#  ('Turkey', 2),
#  ('UAE', 2),
#  ('UK', 10),
#  ('Uruguay', 1),
#  ('USA', 10),
#  ('Venezuela', 1),
#  ('Vietnam', 1)]

# %% [markdown]
# ### Q2. What is the total number of units sold by each store?

# %%
# %%sql
# select
# 	stores.store_id,
# 	stores.store_name,
# 	sum(sales.quantity) total_no_of_units_sold
# from stores
# join sales
# 	on stores.store_id = sales.store_id
# group by 1,2
# order by 3 desc;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 70 rows affected.
# [('ST-5', 'Apple South Coast Plaza', Decimal('47498')),
#  ('ST-3', 'Apple Michigan Avenue', Decimal('44891')),
#  ('ST-4', 'Apple The Grove', Decimal('44784')),
#  ('ST-2', 'Apple Union Square', Decimal('44395')),
#  ('ST-1', 'Apple Fifth Avenue', Decimal('44367')),
#  ('ST-12', 'Apple Yorkdale', Decimal('29882')),
#  ('ST-14', 'Apple Pacific Centre', Decimal('29595')),
#  ('ST-9', 'Apple Lennox Town Center', Decimal('29536')),
#  ('ST-6', 'Apple Scottsdale', Decimal('29504')),
#  ('ST-8', 'Apple Eastview Mall', Decimal('29451')),
#  ('ST-13', 'Apple Square One', Decimal('29357')),
#  ('ST-11', 'Apple Eaton Centre', Decimal('29297')),
#  ('ST-10', 'Apple Tysons Corner', Decimal('29215')),
#  ('ST-7', 'Apple Mall of America', Decimal('29196')),
#  ('ST-53', 'Apple New Delhi', Decimal('27464')),
# ...

# %% [markdown]
# ### Q3. How many sales occurred in December 2023?

# %%
# %%sql
# select
# 	count(sales.sale_id) as total_sales
# from sales
# where to_char(sales.sale_date, 'YYYY-MM') = '2023-12'
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [(32846,)]

# %% [markdown]
# ### Q4. How many stores have never had a warranty claim filed against any of their products?

# %%
# %%sql
# select
# 	count(*) as no_of_stores_with_no_warranty_claims
# from stores
# where store_id not in (
# 	select distinct store_id
# 	from sales
# 	right join warranty
# 		on sales.sale_id = warranty.sale_id
# );
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [(58,)]

# %% [markdown]
# ### Q5. What percentage of warranty claims are marked as "Warranty Void"?
# --warranty void/total * 100

# %%
# %%sql
# select
# 	concat(round(
# 		count(claim_id) / (select count(*) from warranty)::numeric * 100
# 		,0), '%') as warranty_void_claims
# from warranty
# where repair_status = 'Warranty Void';
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [('23%',)]

# %% [markdown]
# ### Q6. Which store had the highest total units sold in the last year?

# %%
# %%sql
# select
# 	sales.store_id,
# 	stores.store_name,
# 	sum(sales.quantity) total_units_sold
# from stores
# join sales
# 	on stores.store_id = sales.store_id
# where extract(year from sales.sale_date) = 2023
# group by 1,2
# order by 3 desc
# limit 1;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [('ST-52', 'Apple Mumbai', Decimal('19804'))]

# %% [markdown]
# ### Q7. Count the number of unique products sold in the last year.

# %%
# %%sql
# select
# 	count(distinct sales.product_id) as no_of_unique_products_sold_last_year
# from sales
# where extract(year from sales.sale_date) = 2023
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [(50,)]

# %% [markdown]
# ### Q8. What is the average price of products in each category?

# %%
# %%sql
# select
# 	category.category_id,
# 	category.category_name,
# 	round(avg(products.price)::numeric,2) as average_product_price
# from category
# join products
# 	on category.category_id = products.category_id
# group by 1,2;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 10 rows affected.
# [('CAT-7', 'Desktop', Decimal('1199.00')),
#  ('CAT-8', 'Subscription Service', Decimal('149.50')),
#  ('CAT-3', 'Tablet', Decimal('656.50')),
#  ('CAT-5', 'Wearable', Decimal('362.33')),
#  ('CAT-1', 'Laptop', Decimal('1511.50')),
#  ('CAT-4', 'Smartphone', Decimal('889.43')),
#  ('CAT-9', 'Smart Speaker', Decimal('99.00')),
#  ('CAT-6', 'Streaming Device', Decimal('179.00')),
#  ('CAT-10', 'Accessory', Decimal('29.00')),
#  ('CAT-2', 'Audio', Decimal('259.00'))]

# %% [markdown]
# ### Q9. How many warranty claims were filed in 2020?

# %%
# %%sql
# select
# 	count(*) as no_of_warranty_claims_2020
# from warranty
# where extract(year from claim_date) = 2020;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [(2750,)]

# %% [markdown]
# ### Q10. Identify each store and best selling day based on highest qty sold

# %%
# %%sql
# with top_sales_rank as (
#   select
# 	  sales.store_id,
# 	  to_char(sales.sale_date, 'day') as day_name,
# 	  sum(sales.quantity) as highest_quantity_sold,
# 	  rank() over(partition by store_id order by sum(quantity) desc) as rank
#   from sales
#   group by 1,2
# )
# select *
# from top_sales_rank
# where rank = 1;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 70 rows affected.
# [('ST-1', 'thursday ', Decimal('6830'), 1),
#  ('ST-10', 'sunday   ', Decimal('4432'), 1),
#  ('ST-11', 'monday   ', Decimal('4314'), 1),
#  ('ST-12', 'sunday   ', Decimal('4539'), 1),
#  ('ST-13', 'monday   ', Decimal('4400'), 1),
#  ('ST-14', 'thursday ', Decimal('4366'), 1),
#  ('ST-15', 'monday   ', Decimal('2879'), 1),
#  ('ST-16', 'monday   ', Decimal('2940'), 1),
#  ('ST-17', 'thursday ', Decimal('2837'), 1),
#  ('ST-18', 'sunday   ', Decimal('2865'), 1),
#  ('ST-19', 'monday   ', Decimal('2985'), 1),
#  ('ST-2', 'thursday ', Decimal('6614'), 1),
#  ('ST-20', 'sunday   ', Decimal('2864'), 1),
#  ('ST-21', 'monday   ', Decimal('3522'), 1),
#  ('ST-22', 'monday   ', Decimal('3388'), 1),
#  ('ST-23', 'monday   ', Decimal('3416'), 1),
#  ('ST-24', 'tuesday  ', Decimal('3443'), 1),
#  ('ST-25', 'friday   ', Decimal('3403'), 1),
# ...

# %% [markdown]
# ### Q11. Identify least selling product of each country for each year based on total unit sold

# %%
# %%sql
# with bottom_sales_rank as
# (
# select
# 	stores.country,
#   extract(year from sales.sale_date) as year,
# 	products.product_name,
# 	sum(sales.quantity) as total_qty_sold,
# 	rank() over(partition by extract(year from sales.sale_date), stores.country order by sum(sales.quantity)) as rank
# from products
# join sales
# 	on products.product_id = sales.product_id
# join stores
# 	on sales.store_id = stores.store_id
# group by 1,2,3
# order by 1,2
# )
# select *
# from bottom_sales_rank
# where rank = 1;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 188 rows affected.
# [('Argentina', Decimal('2021'), 'iPhone 13 Mini', Decimal('28'), 1),
#  ('Argentina', Decimal('2022'), 'iPad Pro (M1, 11-inch)', Decimal('5'), 1),
#  ('Argentina', Decimal('2022'), 'Apple TV 4K', Decimal('5'), 1),
#  ('Argentina', Decimal('2023'), 'iPhone 15 Pro Max', Decimal('139'), 1),
#  ('Argentina', Decimal('2024'), 'iPhone 15', Decimal('60'), 1),
#  ('Australia', Decimal('2020'), 'Apple Fitness+', Decimal('37'), 1),
#  ('Australia', Decimal('2021'), 'Mac mini (M1)', Decimal('28'), 1),
#  ('Australia', Decimal('2021'), 'iPhone 12 Mini', Decimal('28'), 1),
#  ('Australia', Decimal('2022'), 'Apple TV 4K', Decimal('22'), 1),
#  ('Australia', Decimal('2022'), 'iPad Pro (M1, 12.9-inch)', Decimal('22'), 1),
#  ('Australia', Decimal('2022'), 'iMac (24-inch, M1)', Decimal('22'), 1),
# ...

# %% [markdown]
# ### Q12. How many warranty claims were filed within 180 days of a product sale?

# %%
# %%sql
# select
# 	count(warranty.claim_id) as warranty_claims_filed_within_180_days
# from warranty
# left join sales
# 	on warranty.sale_id = sales.sale_id
# where warranty.claim_date - sales.sale_date <= 180;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [(19907,)]

# %% [markdown]
# ### Q13.  Determine how many warranty claims were filed for products launched in the last two years.

# %%
# %%sql
# select
# 	products.product_name,
#   extract(year from products.launch_date) as launch_date,
# 	count(warranty.claim_id) as no_warranty
# from warranty
# join sales on warranty.sale_id = sales.sale_id
# join products on sales.product_id = products.product_id
# where extract(year from products.launch_date) >= 2022
# group by 1,2
# order by 2;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 9 rows affected.
# [('AirPods Pro (2nd Gen)', Decimal('2022'), 913),
#  ('iPad (10th Gen)', Decimal('2022'), 685),
#  ('iPad Pro (M2, 11-inch)', Decimal('2022'), 716),
#  ('iPhone 14', Decimal('2022'), 1321),
#  ('iPhone 14 Pro', Decimal('2022'), 1260),
#  ('iPhone SE (3rd Gen)', Decimal('2022'), 1885),
#  ('iPhone 15', Decimal('2023'), 321),
#  ('iPhone 15 Pro', Decimal('2023'), 290),
#  ('iPhone 15 Pro Max', Decimal('2023'), 320)]

# %% [markdown]
# ### Q.14 List the months in the last three years where sales exceeded 5,000 units in the USA.

# %%
# %%sql
# select
# 	extract(year from sales.sale_date) as year,
# 	extract(month from sales.sale_date) as month,
# 	count(sales.sale_id) as sales_qty
# from sales
# join stores on sales.store_id = stores.store_id
# where extract(year from sales.sale_date) >= 2021
# 	and stores.country = 'USA'
# group by 1,2
# having count(sales.sale_id) > 5000
# order by 1,2;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 9 rows affected.
# [(Decimal('2021'), Decimal('10'), 7861),
#  (Decimal('2021'), Decimal('11'), 7169),
#  (Decimal('2021'), Decimal('12'), 6199),
#  (Decimal('2022'), Decimal('3'), 5831),
#  (Decimal('2022'), Decimal('4'), 5779),
#  (Decimal('2022'), Decimal('9'), 9789),
#  (Decimal('2022'), Decimal('10'), 11005),
#  (Decimal('2022'), Decimal('11'), 11289),
#  (Decimal('2022'), Decimal('12'), 10724)]

# %% [markdown]
# ### Q.15 Identify the product category with the most warranty claims filed in the last two years.

# %%
# %%sql
# select
# 	category.category_name,
# 	count(warranty.claim_id) as no_warranties
# from category
# join products on category.category_id = products.category_id
# join sales on products.product_id = sales.product_id
# join warranty on sales.sale_id = warranty.sale_id
# where extract(year from sales.sale_date) >= 2022
# group by 1
# order by 2 desc
# limit 1;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [('Smartphone', 9244)]

# %% [markdown]
# ### Q.16 Categorize the number of units sold by store as sales being 'high', 'medium', and 'low'.
# *   Determine the ranges of 'high', 'medium', 'low'

# %%
# %%sql
# with sales_range as
# (
# select
# 	stores.store_name,
# 	count(sales.sale_id) as total_units_sold
# from products
# join sales on products.product_id = sales.product_id
# join stores on sales.store_id = stores.store_id
# group by 1
# )
# select
# 	min(total_units_sold) as min,
# 	round((min(total_units_sold) + ((avg(total_units_sold)-min(total_units_sold))/2)),0) as min_range,
# 	round(avg(total_units_sold), 0) as average,
# 	round((avg(total_units_sold) + ((max(total_units_sold)-avg(total_units_sold))/2)),0) as max_range,
# 	max(total_units_sold) as max
# from
# sales_range;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 1 rows affected.
# [(647, Decimal('7753'), Decimal('14860'), Decimal('26168'), 37477)]

# %%
# %%sql
# --using the calculated ranges in above query, display the stores, units_sold, and category
# select
# 	stores.store_name,
# 	count(sales.sale_id) as total_units_sold,
# 	case
# 		when count(sales.sale_id) <= 7753 then 'low'
# 		when count(sales.sale_id) between 7753 and 26168 then 'medium'
# 		when count(sales.sale_id) >= 26168 then 'high'
# 	end as category
# from products
# join sales on products.product_id = sales.product_id
# join stores on sales.store_id = stores.store_id
# group by 1
# order by 2;
# Out:
#  * postgresql://uauixbmmi7hdbhbtx1pg:***@bvgtnd4fd1nog8jcnfvw-postgresql.services.clever-cloud.com:50013/bvgtnd4fd1nog8jcnfvw
# 70 rows affected.
# [('Apple Sheffield', 647, 'low'),
#  ('Apple Birmingham', 678, 'low'),
#  ('Apple Newcastle', 685, 'low'),
#  ('Apple Santo Domingo', 709, 'low'),
#  ('Apple Manchester', 714, 'low'),
#  ('Apple Ho Chi Minh City', 5424, 'low'),
#  ('Apple Buenos Aires', 5489, 'low'),
#  ('Apple Riyadh', 5498, 'low'),
#  ('Apple Doha', 5541, 'low'),
#  ('Apple Manila', 5578, 'low'),
#  ('Apple La Paz', 5586, 'low'),
#  ('Apple Montevideo', 5606, 'low'),
#  ('Apple Caracas', 5610, 'low'),
#  ('Apple San José', 5632, 'low'),
#  ('Apple Lima', 5800, 'low'),
#  ('Apple Mall of the Emirates', 5934, 'low'),
#  ('Apple Hong Kong', 7493, 'low'),
#  ('Apple Santiago', 7523, 'low'),
#  ('Apple Beijing', 7537, 'low'),
#  ('Apple Shanghai', 7550, 'low'),
#  ('Apple Bangkok', 7553, 'low'),
#  ('Apple Chengdu', 7557, 'low'),
#  ('Apple Jakarta', 7583, 'low'),
# ...
